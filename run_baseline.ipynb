# %%
# %run cnn_train.py
# Out:
# Using fc7 feature...
# Using fc7 feature...
# set up dataset variable successfully
# set up dataloader successfully
# training on cpu...
# The parameters number of the model is 25.430288 million
# epoch training...
# ...
# 100%|█████████▉| 952/953 [19:32<00:01,  1.16s/it]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/launchpad/interact/cnn_train.py in <module>
#     384 if __name__ == "__main__":
#     385     data_const = HicoConstants(feat_type=args.feat_type)
# --> 386     run_model(args, data_const)
#
# ~/launchpad/interact/cnn_train.py in run_model(args, data_const)
#     125
#     126     if args.train_model == 'epoch':
# --> 127         epoch_train(model, dataloader, dataset, criterion, optimizer, scheduler, device, data_const)
#     128     else:
#     129         iteration_train(model, dataloader, dataset, criterion, optimizer, scheduler, device, data_const)
#
# ...

# %%
# %run ipnet_train.py
# Out:
# Using fc7 feature...
# Using fc7 feature...
# set up dataset variable successfully
# set up dataloader successfully
# training on cuda...
# The parameters number of the model is 25.430288 million
# epoch training...
#   0%|          | 0/953 [00:00<?, ?it/s]
# batch size:  32
# <PIL.Image.Image image mode=RGB size=640x471 at 0x7F91575E04E0>
# <PIL.Image.Image image mode=RGB size=640x471 at 0x7F91575E04E0>
# <PIL.Image.Image image mode=RGB size=640x471 at 0x7F91575E04E0>
# <PIL.Image.Image image mode=RGB size=640x471 at 0x7F91575E04E0>
# <PIL.Image.Image image mode=RGB size=640x471 at 0x7F91575E04E0>
# <PIL.Image.Image image mode=RGB size=640x471 at 0x7F91575E04E0>
# <PIL.Image.Image image mode=RGB size=640x471 at 0x7F91575E04E0>
# <PIL.Image.Image image mode=RGB size=640x471 at 0x7F91575E04E0>
# <PIL.Image.Image image mode=RGB size=640x471 at 0x7F91575E04E0>
# <PIL.Image.Image image mode=RGB size=640x471 at 0x7F91575E04E0>
# ...
